# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 7.2/7.2 MB 669.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.3/3.3 MB 241.1 kB/s eta 0:00:00
# ...
#      ------------------------------------ 164.1/164.1 kB 246.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 55.3/55.3 kB 360.2 kB/s eta 0:00:00
# ...
#      ------------------------------------ 960.8/960.8 kB 191.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.6.0'

# %%
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# import dependencies
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan,", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of  floats as the total fare in the US dollars.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot eith ax-plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot
plt.plot(x_axis, y_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, label = 'Boston')
# Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title
plt.title("PyBer Fare by Month")
# Add the legend
plt.legend()

# %%
# Create the plot
plt.plot(x_axis, y_axis, marker="", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
#Set the y limit between 0 and 45
plt.ylim(0, 45)
# Create a title axes labels
plt.title("PyBer Fare by Month")
# Add a grid
plt.grid()
# Add the legend
plt.legend()

# %%
# Set the x-axis to a lost of strings for each month
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in the US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
#Create a title
plt.title("PyBer Fare by Month")
# Add the legend
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Create the plot
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
# Create a title annd x and y labels
plt.title("PyBer Fare by Month")
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a lost of strings for each month
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in the US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
 # Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label='Chicago')
#Add title and labels
plt.title("PyBer Fare by Month")
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Invert the y-axis data
plt.gca().invert_yaxis()
# Add legend
plt.legend()

# %%
# Set the x-axis to a lost of strings for each month
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in the US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
# Create the plot
plt.scatter(y_axis, x_axis, color="red", label='Chicago')
# Add a title and axes labels
plt.title("PyBer Fare by Month")
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Add a limit to the x-axis
plt.xlim(0, 50)
# Invert the y-axis so that Jan is at the top
plt.gca().invert_yaxis()
# Add a legend
plt.legend()

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
#code to make the markers bigger
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# list comprehension that can replace 'for' and 'while' loops
new_list = [expression for item in list if conditional]
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [78], line 1
# ----> 1 plt.scatter = [expression for item in list if conditional]
#       2 plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])
#
# TypeError: 'type' object is not iterable

# %%
# create a scatter plot using the object_oriented approach
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# create a bubble chart using the object_oriented approach
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
 # create the plot for scatter chart
fig, ax = plt.subplots()  
ax.scatter(x_axis, y_axis, s=y_axis, color="skyblue", label='Boston')
# Add title and labels
plt.title("PyBer Fare by Month")
plt.x_axis("Fare($)")
plt.y_axis("Date")
#change the size of the markers to 5* each data point
y_axis_larger
for data in y_axis:
    y_axis_larger.append(data*5)
plt.scatter(x_axis, y_axis, s=y_axis_larger)
# add a limit for the x-axis
plt.xlim(0, 50)
# invert the y-axis so that january is on top
plt.gca().invert_yaxis()
# Add a legend
plt.legend()
# make the color 20% transparent
# add a black edge color to the circles
# make the linewidth of the circles 2 pts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [86], line 6
#       4 # Add title and labels
#       5 plt.title("PyBer Fare by Month")
# ----> 6 ax.x_axis("Fare($)")
#       7 ax.y_axis("Date")
#       8 #change the size of the markers to 5* each data point
#
# AttributeError: 'AxesSubplot' object has no attribute 'x_axis'

# %%
# create pie chart
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
# make pie chart bigger
plt.subplots(figsize=(9, 9))
# add values to pie chart
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='1%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2cdcc2a5e10>,
# ...
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '13.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '17.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '113.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '111.7%'),
# ...

# %%
# assign 12 colors, one for each month
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", 
          "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8,8))
plt.pie(y_axis, 
        explode=explode_values,
        colors=colors,
        labels=x_axis, 
        autopct='1%.1f%%')
plt.show()

# %%
#create a pie chart using object-oriented approach
fig, ax = plt.subplots()
ax.pie(y_axis, 
       labels=x_axis, 
       explode=explode_values,
        autopct='1%.1f%%',
      colors=colors)
# explode the 2 highest percentage months
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
# increase the figure size to 8x8
plt.subplots(figsize=(9, 9))
# add colors
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", 
          "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

plt.show()
